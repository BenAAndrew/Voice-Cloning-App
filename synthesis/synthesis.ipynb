# %%
import sys
sys.path.append('waveglow/')
sys.path.append('../')
from training.tacotron2_model import Tacotron2, TacotronSTFT
import numpy as np
import torch
import inflect
from synthesize import load_model, load_waveglow, synthesize, text_to_sequence
from text import text_to_sequence as text_to_sequence_old
import IPython.display as ipd

import matplotlib
# %matplotlib inline
import matplotlib.pylab as plt

# %% [markdown]
# #### Import models

# %%
checkpoint_path = "../training/checkpoints3/checkpoint_163000"
waveglow_path = "../waveglow_256channels_universal_v5.pt"

# %%
model = load_model(checkpoint_path)
waveglow = load_waveglow(waveglow_path)
inflect_engine = inflect.engine()
# Out:
# /home/iot11/anaconda3/envs/voice-synth/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.conv.ConvTranspose1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/iot11/anaconda3/envs/voice-synth/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %% [markdown]
# #### Synthesis

# %%
text = "There is a way to measure the acute emotional intelligence that has never gone out of style."
graph = "graph.png"
audio = "audio.wav"

# %%
synthesize(model, waveglow, text, inflect_engine, graph, audio)

# %%
ipd.Audio("audio.wav", rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
