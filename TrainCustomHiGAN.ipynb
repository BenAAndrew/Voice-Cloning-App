# %% [markdown]
# # Voice Cloning App - Remote Training
#
# Remote training for the Voice Cloning App.
#
# **Please ensure you have this notebook enabled with GPU before running (Runtime->Change runtime type)**
#
# Steps:
# 1. Export your dataset from the app & unzip
# 2. Create a folder called `Voice-Cloning` in your Google Drive
#   1. Create a sub-folder called `datasets` and upload your dataset folder to it
#   2. If using non-English: Create a sub folder called `alphabets` and upload your alphabet.txt file to it
# 3. Configure parameters below
# 4. Run this notebook one cell at a time
#   - Connect to your google drive when prompted
#   - Ensure you have selected the correct options before running the training cell
#
# During training and once training is done you'll find your latest checkpoint in Google Drive within the folder `Voice-Cloning/checkpoints/dataset_name`.
#
# This can be download from your drive and imported into the app under the "Import/Export" menu.

# %%
#@title Connect to google drive
from google.colab import drive
import os

drive.mount('/content/drive')

output_directory = "/content/drive/MyDrive/Voice-Cloning"
os.makedirs(output_directory, exist_ok=True)

dataset_directory = os.path.join(output_directory, "datasets")
os.makedirs(output_directory, exist_ok=True)

hifigan_directory = os.path.join(output_directory, "hifigan_training")
os.makedirs(output_directory, exist_ok=True)

checkpoint_directory = hifigan_directory
os.makedirs(checkpoint_directory, exist_ok=True)

alphabet_directory = os.path.join(output_directory, "alphabets")
os.makedirs(alphabet_directory, exist_ok=True)

datasets = os.listdir(dataset_directory)
assert datasets, "No datasets found in 'Voice-Cloning/datasets'. Please export your dataset from the app, unzip and upload to this folder"

# Check datasets
for dataset in datasets:
  try:
    dataset_path = os.path.join(dataset_directory, dataset)
    files = os.listdir(dataset_path)
    assert "metadata.csv" in files, f"Dataset '{dataset}' is missing metadata.csv"
    assert "wavs" in files, f"Dataset '{dataset}' is missing wavs folder"
  except NotADirectoryError:
    raise Exception(f"Dataset '{dataset}' is not a folder. Please ensure all datasets are folders containing your metadata.csv & wavs")

checkpoints = {dataset: os.listdir(os.path.join(hifigan_directory, dataset)) for dataset in datasets if os.path.isdir(os.path.join(checkpoint_directory, dataset))}
languages = os.listdir(alphabet_directory)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title Parameters
import torch
from torch.utils.data import DataLoader
import torch.nn.functional as F
import argparse
import itertools
import logging
import json
import time
import os
from os.path import dirname, abspath
assert torch.cuda.is_available(),  "Please change Runtime type to GPU (Runtime->Change runtime type)"

# Clone the app
# !pip install pysrt==1.1.2 pydub==0.24.1 webrtcvad==2.0.10 Unidecode==1.0.22
# !git clone https://github.com/BenAAndrew/Voice-Cloning-App.git
# %cd /content/Voice-Cloning-App/
#git checkout 0965a3c8b217dceaf60e22f9fd6b6ceab990c82f
from training import DEFAULT_ALPHABET
from training.utils import load_symbols
from training.train import train
from training.hifigan.train import train as train_hifigan
from training.hifigan.utils import get_checkpoint_options, save_checkpoints
from training.hifigan.utils import checkpoint_cleanup as hifigan_checkpoint_cleanup


# Download pretrained model
#from google_drive_downloader import GoogleDriveDownloader as gdd
#transfer_learning_path = "pretrained.pt"
#gdd.download_file_from_google_drive(file_id='1c5ZTuT7J08wLUoVZ2KkUs_VdZuJ86ZqA', dest_path="./"+transfer_learning_path, unzip=False)

# Get settings
epochs = 1000 #@param {type:"slider", min:100, max:3500, step:100}
batch_size = 38 #@param {type:"slider", min:12, max:70, step:2}
checkpoint_frequency = 1000 #@param {type:"slider", min:250, max:2500, step:250}
backup_checkpoint_frequency = 10000 #@param {type:"slider", min:2500, max:25000, step:500}
validation_size = 0.2 #@param {type:"slider", min:0.05, max:0.2, step:0.025}
early_stopping = True #@param {type:"boolean"}
# Out:
# Requirement already satisfied: pysrt==1.1.2 in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: pydub==0.24.1 in /usr/local/lib/python3.7/dist-packages (0.24.1)
# Requirement already satisfied: webrtcvad==2.0.10 in /usr/local/lib/python3.7/dist-packages (2.0.10)
# Requirement already satisfied: Unidecode==1.0.22 in /usr/local/lib/python3.7/dist-packages (1.0.22)
# Requirement already satisfied: chardet in /usr/local/lib/python3.7/dist-packages (from pysrt==1.1.2) (3.0.4)
# Cloning into 'Voice-Cloning-App'...
# remote: Enumerating objects: 3124, done.
# remote: Counting objects: 100% (1939/1939), done.
# remote: Compressing objects: 100% (1191/1191), done.
# remote: Total 3124 (delta 1371), reused 1227 (delta 709), pack-reused 1185
# Receiving objects: 100% (3124/3124), 15.48 MiB | 10.70 MiB/s, done.
# Resolving deltas: 100% (2096/2096), done.
# /content/Voice-Cloning-App

# %%
#@title Options
import ipywidgets as widgets
from IPython.display import display

# Form
dataset = widgets.Dropdown(
    options=datasets,
    description='Dataset:',
)

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
      checkpoint.options = checkpoints.get(change['new'], [])

dataset.observe(on_change)

checkpointg = widgets.Dropdown(
    options=checkpoints.get(dataset.value, []),
    description='Checkpoint g:',
)

checkpointdo = widgets.Dropdown(
    options=checkpoints.get(dataset.value, []),
    description='Checkpoint do:',
)

alphabet = widgets.Dropdown(
    options=languages,
    description='Language:',
)

button = widgets.Button(
    description="Start training", 
    button_style="success",
)

display(dataset)
display(checkpointg)
display(checkpointdo)
if languages:
  display(alphabet)
# Out:
# Dropdown(description='Dataset:', options=('RCBray',), value='RCBray')
# Dropdown(description='Checkpoint g:', options=('do_5000', 'g_5000', 'g_1000', 'do_1000'), value='do_5000')
# Dropdown(description='Checkpoint do:', options=('do_5000', 'g_5000', 'g_1000', 'do_1000'), value='do_5000')

# %%
#@title Train

dataset_path = os.path.join(dataset_directory, dataset.value)

wavs = os.path.join(dataset_path, "wavs")
output_directory = os.path.join(hifigan_directory, dataset.value)
symbols = load_symbols(os.path.join(alphabet_directory, alphabet.value)) if alphabet.value else DEFAULT_ALPHABET
checkpoint_path = os.path.join(hifigan_directory, dataset.value, checkpoint.value) if checkpoint.value else None
train_hifigan(
     audio_folder=wavs,
    output_directory=output_directory,
    checkpoint_g= os.path.join(hifigan_directory, dataset.value, checkpointg.value),
    checkpoint_do=os.path.join(hifigan_directory, dataset.value, checkpointdo.value),
    epochs=1000,
    batch_size=None,
    iters_per_checkpoint=1000,
    iters_per_backup_checkpoint=10000,
    train_size=0.8,
    logging=logging
)
# Out:
# INFO:root:Setting batch size to 8, learning rate to 0.000282842712474619. (10GB GPU memory free)
# 3417 train files, 855 test files
# INFO:root:Loading /content/drive/MyDrive/Voice-Cloning/hifigan_training/RCBray/g_5000 and /content/drive/MyDrive/Voice-Cloning/hifigan_training/RCBray/do_5000 checkpoints
# Epoch: 1
# INFO:root:Status - [Epoch 0: Iteration 5001] Loss 26.336 Mel-Spec. Error 0.38162 0.97s/it
# INFO:root:Status - [Epoch 0: Iteration 5002] Loss 27.411 Mel-Spec. Error 0.42971 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5003] Loss 28.341 Mel-Spec. Error 0.44262 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5004] Loss 30.954 Mel-Spec. Error 0.47179 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5005] Loss 27.138 Mel-Spec. Error 0.43016 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5006] Loss 33.879 Mel-Spec. Error 0.51388 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5007] Loss 33.875 Mel-Spec. Error 0.57576 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5008] Loss 33.967 Mel-Spec. Error 0.54923 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5009] Loss 35.422 Mel-Spec. Error 0.51613 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5010] Loss 33.653 Mel-Spec. Error 0.51063 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5011] Loss 33.448 Mel-Spec. Error 0.52939 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5012] Loss 33.385 Mel-Spec. Error 0.55216 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5013] Loss 32.815 Mel-Spec. Error 0.50328 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5014] Loss 30.848 Mel-Spec. Error 0.46921 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5015] Loss 28.407 Mel-Spec. Error 0.45004 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5016] Loss 32.465 Mel-Spec. Error 0.50115 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5017] Loss 34.606 Mel-Spec. Error 0.51553 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5018] Loss 30.776 Mel-Spec. Error 0.48901 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5019] Loss 34.119 Mel-Spec. Error 0.52050 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5020] Loss 31.651 Mel-Spec. Error 0.54016 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5021] Loss 38.884 Mel-Spec. Error 0.61843 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5022] Loss 36.231 Mel-Spec. Error 0.55425 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5023] Loss 33.061 Mel-Spec. Error 0.52273 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5024] Loss 34.355 Mel-Spec. Error 0.55212 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5025] Loss 30.769 Mel-Spec. Error 0.48881 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5026] Loss 30.727 Mel-Spec. Error 0.49004 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5027] Loss 35.073 Mel-Spec. Error 0.60692 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5028] Loss 34.335 Mel-Spec. Error 0.57294 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5029] Loss 31.366 Mel-Spec. Error 0.52810 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5030] Loss 31.565 Mel-Spec. Error 0.53440 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5031] Loss 29.694 Mel-Spec. Error 0.49156 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5032] Loss 30.201 Mel-Spec. Error 0.49864 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5033] Loss 30.502 Mel-Spec. Error 0.49502 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5034] Loss 32.109 Mel-Spec. Error 0.50783 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5035] Loss 27.719 Mel-Spec. Error 0.46850 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5036] Loss 30.249 Mel-Spec. Error 0.53885 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5037] Loss 31.206 Mel-Spec. Error 0.51501 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5038] Loss 33.564 Mel-Spec. Error 0.50350 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5039] Loss 34.002 Mel-Spec. Error 0.51873 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5040] Loss 33.276 Mel-Spec. Error 0.47183 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5041] Loss 31.203 Mel-Spec. Error 0.45983 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5042] Loss 34.152 Mel-Spec. Error 0.48811 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5043] Loss 33.707 Mel-Spec. Error 0.50328 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5044] Loss 31.049 Mel-Spec. Error 0.46078 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5045] Loss 28.975 Mel-Spec. Error 0.44640 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5046] Loss 30.209 Mel-Spec. Error 0.45726 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5047] Loss 27.760 Mel-Spec. Error 0.44334 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5048] Loss 28.436 Mel-Spec. Error 0.44399 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5049] Loss 28.955 Mel-Spec. Error 0.43613 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5050] Loss 30.088 Mel-Spec. Error 0.45945 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5051] Loss 28.432 Mel-Spec. Error 0.45772 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5052] Loss 30.224 Mel-Spec. Error 0.46166 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5053] Loss 28.983 Mel-Spec. Error 0.45973 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5054] Loss 30.497 Mel-Spec. Error 0.45865 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5055] Loss 31.238 Mel-Spec. Error 0.45428 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5056] Loss 32.316 Mel-Spec. Error 0.44952 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5057] Loss 29.371 Mel-Spec. Error 0.46371 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5058] Loss 35.796 Mel-Spec. Error 0.55692 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5059] Loss 31.624 Mel-Spec. Error 0.47730 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5060] Loss 31.378 Mel-Spec. Error 0.49221 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5061] Loss 30.683 Mel-Spec. Error 0.45289 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5062] Loss 32.233 Mel-Spec. Error 0.48933 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5063] Loss 29.770 Mel-Spec. Error 0.45130 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5064] Loss 30.313 Mel-Spec. Error 0.44488 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5065] Loss 28.558 Mel-Spec. Error 0.42779 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5066] Loss 28.046 Mel-Spec. Error 0.42676 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5067] Loss 33.329 Mel-Spec. Error 0.49428 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5068] Loss 30.669 Mel-Spec. Error 0.46388 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5069] Loss 31.777 Mel-Spec. Error 0.45634 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5070] Loss 31.586 Mel-Spec. Error 0.47058 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5071] Loss 31.158 Mel-Spec. Error 0.45647 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5072] Loss 30.373 Mel-Spec. Error 0.43672 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5073] Loss 32.065 Mel-Spec. Error 0.46519 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5074] Loss 32.200 Mel-Spec. Error 0.48637 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5075] Loss 31.666 Mel-Spec. Error 0.46673 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5076] Loss 28.445 Mel-Spec. Error 0.42695 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5077] Loss 29.763 Mel-Spec. Error 0.45272 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5078] Loss 30.209 Mel-Spec. Error 0.47204 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5079] Loss 30.928 Mel-Spec. Error 0.46461 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5080] Loss 31.661 Mel-Spec. Error 0.45906 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5081] Loss 30.386 Mel-Spec. Error 0.44693 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5082] Loss 29.549 Mel-Spec. Error 0.42865 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5083] Loss 29.677 Mel-Spec. Error 0.45304 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5084] Loss 28.894 Mel-Spec. Error 0.44028 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5085] Loss 25.719 Mel-Spec. Error 0.42425 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5086] Loss 30.113 Mel-Spec. Error 0.44384 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5087] Loss 30.976 Mel-Spec. Error 0.46883 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5088] Loss 32.139 Mel-Spec. Error 0.45953 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5089] Loss 26.723 Mel-Spec. Error 0.41262 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5090] Loss 30.824 Mel-Spec. Error 0.46510 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5091] Loss 28.612 Mel-Spec. Error 0.43517 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5092] Loss 30.770 Mel-Spec. Error 0.47818 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5093] Loss 29.788 Mel-Spec. Error 0.45984 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5094] Loss 28.684 Mel-Spec. Error 0.43345 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5095] Loss 31.089 Mel-Spec. Error 0.47411 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5096] Loss 32.820 Mel-Spec. Error 0.49285 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5097] Loss 31.550 Mel-Spec. Error 0.46938 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5098] Loss 32.223 Mel-Spec. Error 0.50672 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5099] Loss 29.834 Mel-Spec. Error 0.46171 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5100] Loss 32.895 Mel-Spec. Error 0.50055 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5101] Loss 32.999 Mel-Spec. Error 0.49257 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5102] Loss 31.827 Mel-Spec. Error 0.46195 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5103] Loss 32.692 Mel-Spec. Error 0.48828 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5104] Loss 34.874 Mel-Spec. Error 0.49834 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5105] Loss 30.679 Mel-Spec. Error 0.46709 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5106] Loss 34.963 Mel-Spec. Error 0.49420 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5107] Loss 33.542 Mel-Spec. Error 0.50327 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5108] Loss 34.832 Mel-Spec. Error 0.52021 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5109] Loss 28.297 Mel-Spec. Error 0.41374 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5110] Loss 32.133 Mel-Spec. Error 0.48020 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5111] Loss 30.868 Mel-Spec. Error 0.45870 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5112] Loss 30.747 Mel-Spec. Error 0.46183 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5113] Loss 31.126 Mel-Spec. Error 0.46664 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5114] Loss 30.671 Mel-Spec. Error 0.46171 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5115] Loss 31.228 Mel-Spec. Error 0.47638 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5116] Loss 32.878 Mel-Spec. Error 0.47018 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5117] Loss 29.427 Mel-Spec. Error 0.43898 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5118] Loss 30.470 Mel-Spec. Error 0.47638 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5119] Loss 25.380 Mel-Spec. Error 0.39648 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5120] Loss 29.575 Mel-Spec. Error 0.45924 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5121] Loss 28.954 Mel-Spec. Error 0.45078 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5122] Loss 30.558 Mel-Spec. Error 0.45645 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5123] Loss 30.093 Mel-Spec. Error 0.45950 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5124] Loss 30.683 Mel-Spec. Error 0.45842 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5125] Loss 27.648 Mel-Spec. Error 0.41596 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5126] Loss 32.425 Mel-Spec. Error 0.49128 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5127] Loss 27.596 Mel-Spec. Error 0.42972 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5128] Loss 30.583 Mel-Spec. Error 0.47347 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5129] Loss 29.784 Mel-Spec. Error 0.44595 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5130] Loss 31.592 Mel-Spec. Error 0.48964 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5131] Loss 31.285 Mel-Spec. Error 0.46934 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5132] Loss 32.187 Mel-Spec. Error 0.46434 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5133] Loss 27.846 Mel-Spec. Error 0.45422 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5134] Loss 30.856 Mel-Spec. Error 0.49149 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5135] Loss 27.915 Mel-Spec. Error 0.42162 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5136] Loss 28.983 Mel-Spec. Error 0.44177 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5137] Loss 31.901 Mel-Spec. Error 0.46902 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5138] Loss 31.094 Mel-Spec. Error 0.45470 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5139] Loss 32.755 Mel-Spec. Error 0.49477 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5140] Loss 32.059 Mel-Spec. Error 0.46308 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5141] Loss 33.783 Mel-Spec. Error 0.47331 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5142] Loss 34.588 Mel-Spec. Error 0.50621 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5143] Loss 33.648 Mel-Spec. Error 0.47899 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5144] Loss 33.020 Mel-Spec. Error 0.49766 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5145] Loss 29.625 Mel-Spec. Error 0.46427 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5146] Loss 32.595 Mel-Spec. Error 0.49005 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5147] Loss 29.201 Mel-Spec. Error 0.43658 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5148] Loss 32.483 Mel-Spec. Error 0.47565 0.96s/it
# INFO:root:Status - [Epoch 0: Iteration 5149] Loss 34.302 Mel-Spec. Error 0.50342 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5150] Loss 32.060 Mel-Spec. Error 0.47544 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5151] Loss 30.514 Mel-Spec. Error 0.44497 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5152] Loss 32.662 Mel-Spec. Error 0.48885 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5153] Loss 29.014 Mel-Spec. Error 0.42685 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5154] Loss 28.342 Mel-Spec. Error 0.42241 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5155] Loss 27.960 Mel-Spec. Error 0.41976 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5156] Loss 28.034 Mel-Spec. Error 0.40909 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5157] Loss 31.455 Mel-Spec. Error 0.46498 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5158] Loss 26.089 Mel-Spec. Error 0.40753 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5159] Loss 29.019 Mel-Spec. Error 0.43172 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5160] Loss 28.624 Mel-Spec. Error 0.42280 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5161] Loss 27.687 Mel-Spec. Error 0.42463 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5162] Loss 31.352 Mel-Spec. Error 0.48893 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5163] Loss 30.247 Mel-Spec. Error 0.45707 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5164] Loss 29.368 Mel-Spec. Error 0.43710 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5165] Loss 30.088 Mel-Spec. Error 0.44958 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5166] Loss 24.103 Mel-Spec. Error 0.40323 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5167] Loss 27.957 Mel-Spec. Error 0.43014 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5168] Loss 27.756 Mel-Spec. Error 0.44046 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5169] Loss 31.124 Mel-Spec. Error 0.46615 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5170] Loss 28.052 Mel-Spec. Error 0.44164 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5171] Loss 29.844 Mel-Spec. Error 0.44213 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5172] Loss 29.845 Mel-Spec. Error 0.45294 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5173] Loss 29.802 Mel-Spec. Error 0.44177 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5174] Loss 29.058 Mel-Spec. Error 0.46217 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5175] Loss 31.599 Mel-Spec. Error 0.47130 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5176] Loss 28.678 Mel-Spec. Error 0.44638 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5177] Loss 33.202 Mel-Spec. Error 0.49447 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5178] Loss 30.441 Mel-Spec. Error 0.46623 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5179] Loss 33.628 Mel-Spec. Error 0.49172 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5180] Loss 29.568 Mel-Spec. Error 0.47398 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5181] Loss 32.728 Mel-Spec. Error 0.47095 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5182] Loss 31.816 Mel-Spec. Error 0.46224 0.96s/it
# INFO:root:Status - [Epoch 0: Iteration 5183] Loss 31.942 Mel-Spec. Error 0.46660 0.96s/it
# INFO:root:Status - [Epoch 0: Iteration 5184] Loss 28.743 Mel-Spec. Error 0.42736 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5185] Loss 29.639 Mel-Spec. Error 0.46066 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5186] Loss 28.436 Mel-Spec. Error 0.44559 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5187] Loss 29.894 Mel-Spec. Error 0.45621 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5188] Loss 32.271 Mel-Spec. Error 0.45955 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5189] Loss 31.573 Mel-Spec. Error 0.46951 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5190] Loss 30.961 Mel-Spec. Error 0.46694 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5191] Loss 31.912 Mel-Spec. Error 0.46290 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5192] Loss 28.085 Mel-Spec. Error 0.42458 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5193] Loss 29.909 Mel-Spec. Error 0.42381 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5194] Loss 30.105 Mel-Spec. Error 0.43316 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5195] Loss 30.501 Mel-Spec. Error 0.43849 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5196] Loss 28.586 Mel-Spec. Error 0.43860 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5197] Loss 26.326 Mel-Spec. Error 0.41567 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5198] Loss 26.881 Mel-Spec. Error 0.41137 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5199] Loss 26.660 Mel-Spec. Error 0.42445 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5200] Loss 29.979 Mel-Spec. Error 0.46289 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5201] Loss 30.188 Mel-Spec. Error 0.47110 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5202] Loss 24.533 Mel-Spec. Error 0.39766 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5203] Loss 28.746 Mel-Spec. Error 0.42748 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5204] Loss 28.069 Mel-Spec. Error 0.44108 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5205] Loss 25.850 Mel-Spec. Error 0.41438 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5206] Loss 31.054 Mel-Spec. Error 0.50008 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5207] Loss 28.641 Mel-Spec. Error 0.44865 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5208] Loss 30.280 Mel-Spec. Error 0.48570 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5209] Loss 30.825 Mel-Spec. Error 0.46897 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5210] Loss 29.709 Mel-Spec. Error 0.46324 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5211] Loss 31.248 Mel-Spec. Error 0.47527 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5212] Loss 31.717 Mel-Spec. Error 0.47566 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5213] Loss 30.129 Mel-Spec. Error 0.45361 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5214] Loss 30.147 Mel-Spec. Error 0.46519 0.96s/it
# INFO:root:Status - [Epoch 0: Iteration 5215] Loss 30.664 Mel-Spec. Error 0.47515 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5216] Loss 32.607 Mel-Spec. Error 0.49260 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5217] Loss 31.886 Mel-Spec. Error 0.44386 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5218] Loss 29.015 Mel-Spec. Error 0.43232 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5219] Loss 31.270 Mel-Spec. Error 0.44562 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5220] Loss 32.712 Mel-Spec. Error 0.48036 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5221] Loss 30.961 Mel-Spec. Error 0.44517 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5222] Loss 27.124 Mel-Spec. Error 0.42298 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5223] Loss 32.971 Mel-Spec. Error 0.49155 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5224] Loss 30.470 Mel-Spec. Error 0.46629 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5225] Loss 28.628 Mel-Spec. Error 0.44298 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5226] Loss 27.568 Mel-Spec. Error 0.41869 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5227] Loss 30.812 Mel-Spec. Error 0.46242 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5228] Loss 30.720 Mel-Spec. Error 0.47253 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5229] Loss 28.762 Mel-Spec. Error 0.41917 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5230] Loss 31.068 Mel-Spec. Error 0.45787 0.95s/it
# INFO:root:Status - [Epoch 0: Iteration 5231] Loss 31.995 Mel-Spec. Error 0.46992 0.95s/it
